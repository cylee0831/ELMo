# %% [markdown]
# Table of Content
#
# - 甚麼是 ELMo
# - 定義問題
# - Data
# - 使用 Python 實作 ELMo

# %% [markdown]
# ### 甚麼是 ELMo
#
# word embedding 的方法，透過雙層的雙向語言模型計算而來
#
# ELMo 與其他 word embedding 的差別在於
#
# 傳統的 word embedding 方法不管意思為何，每個單詞都只會擁有一個 vector
#
# 而 ELMo 分配給單詞的 ELMo vector 會透過分析整個句子而來
#
# 所以同個單詞在不同的句子中會產生不同的 ELMo vector

# %% [markdown]
# ### 定義問題
#
# 此篇文章的目標是使用 NLP 進行情感分析 <br>
# 從客戶對技術公司的推文，分辨是否包含負面的評價 <br>
# ### Data
#
# 分析的資料來源為 https://datahack.analyticsvidhya.com/contest/linguipedia-codefest-natural-language-processing-1/#data_dictionary
#
# 共有兩個檔案，分別為「測試資料」及「訓練資料」 <br>
# - train data: 共有 7920 筆資料，資料內容包含 ID、label 以及評論
# - test data: 共有 1953 筆資料，資料內容只有 ID 和評論

# %% [markdown]
# ### 使用 Python 實作 ELMo
#
# 在實作之前先安裝好所需的 Library

# %%
import pandas as pd
import numpy as np
import spacy
import re
import time
import pickle

# %% [markdown]
# **step1 : Read Data**

# %%
train = pd.read_csv("train_2kmZucJ.csv")
# test = pd.read_csv("test_oJQbWVk.csv")

train.shape
# Out:
# (7920, 3)

# %%
train.head()
# Out:
#    id  label                                              tweet
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...

# %% [markdown]
# 準備好訓練資料後，我們來看一下正面及負面評價的比例

# %%
train['label'].value_counts(normalize = True)
# Out:
# 0    0.744192
# 1    0.255808
# Name: label, dtype: float64

# %% [markdown]
# **step2 : Data Preprocessing**
#
# 需要做的前處理有下列 6 項: <br>
# - 去掉 URL
# - 去除標點符號
# - 字母轉為小寫
# - 移除數字
# - 去除空白
# - 將多型態的單詞轉回基本形式

# %%
# remove URL's from train and test
train['clean_tweet'] = train['tweet'].apply(lambda x: re.sub(r'http\S+', '', x)) # \S 非空白字元
# test['clean_tweet'] = test['tweet'].apply(lambda x: re.sub(r'http\S+', '', x))

# %%
# remove punctuation marks
punctuation = '!"#$%&()*+-/:;<=>?@[\\]^_`{|}~'

train['clean_tweet'] = train['clean_tweet'].apply(lambda x: ''.join(ch for ch in x if ch not in set(punctuation)))
# test['clean_tweet'] = test['clean_tweet'].apply(lambda x: ''.join(ch for ch in x if ch not in set(punctuation)))

# %%
# convert text to lowercase
train['clean_tweet'] = train['clean_tweet'].str.lower()
# test['clean_tweet'] = test['clean_tweet'].str.lower()

# %%
# remove numbers
train['clean_tweet'] = train['clean_tweet'].str.replace("[0-9]", " ")
# test['clean_tweet'] = test['clean_tweet'].str.replace("[0-9]", " ")

# %%
# remove mutiple whitespaces
train['clean_tweet'] = train['clean_tweet'].apply(lambda x:' '.join(x.split()))
# test['clean_tweet'] = test['clean_tweet'].apply(lambda x: ' '.join(x.split()))

# %% [markdown]
# **將多型態的單詞轉回基本形式**
#
# 我們將使用 spacy 提供的語言模型 <br>
# 在 load "en" 模型前，先下載模型(以下為使用 anaconda 的步驟)
# 1. 使用系統管理員開啟 anaconda
# 2. 開啟 anaconda 的 terminal，輸入下列指令 <br>
#     `python -m spacy download en` (Ubuntu 直接執行此行指令)
#
# 模型下載成功後就可以 load 模型了
#
# 接著我們先來看一下該如何使用 spacy 的模型

# %%
nlp = spacy.load('en')

doc = nlp(u'Apple is looking at buying U.K. startup for $1 billion')

for token in doc:
    print(token.text, token.lemma_)
# Out:
# Apple apple
# is be
# looking look
# at at
# buying buy
# U.K. u.k.
# startup startup
# for for
# $ $
# 1 1
# billion billion

# %%
# lemmatize text

# import spaCy's language model
nlp = spacy.load('en', disable=['parser', 'ner'])

# function to lemmatize text
def lemmatization(texts):
    output = []
    for i in texts:
        s = [token.lemma_ for token in nlp(i)]
        output.append(' '.join(s))
    return output

train['clean_tweet'] = lemmatization(train['clean_tweet'])
# test['clean_tweet'] = lemmatization(test['clean_tweet'])

# %%
train.head()
# Out:
#    id  label                                              tweet  \
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...
#
#                                          clean_tweet
# 0  fingerprint pregnancy test android app beautif...
# 1  finally a transparant silicon case thank to -P...
# 2  -PRON- love this would -PRON- go talk makememo...
# 3  -PRON- be wired i know -PRON- be george i be m...
# 4  what amazing service apple will not even talk ...

# %% [markdown]
# **step3 : 準備 ELMo vectors**
#
# 我們將使用套件 TensorFlow 來實現
#
# 先安裝套件 tensorflow 1.7.0 版及 tensorflow-hub <br>
#
# `pip install "tensorflow>=1.7.0"` <br>
# `pip install tensorflow-hub` <br>
#
# 接著 import 已經訓練好的 ELMo model

# %%
import tensorflow_hub as hub
import tensorflow as tf

elmo = hub.Module("https://tfhub.dev/google/elmo/2", trainable=True)

# %% [markdown]
# 這樣就成功的取得了 ELMo 模型
#
# 接著讓我們用個簡單的範例來看一下該如何生成 ELMo vector

# %%
x = ["Roasted ants are a popular snack in Columbia"]

embeddings = elmo(x, signature="default", as_dict=True)["elmo"]

embeddings.shape
# Out:
# TensorShape([Dimension(1), Dimension(8), Dimension(1024)])

# %% [markdown]
# 輸出的結果會是三維的，內容分別是: <br>
# - 輸入的句子數量
# - 最長的句子數
# - 每個單詞的 ELMo vector 長度
#
# 轉換完成後，使用 tf 取得 ELMo vector

# %%
with tf.Session() as sess: # 創建一個tensorflow session
    sess.run(tf.global_variables_initializer())
    sess.run(tf.tables_initializer())
    # return average of ELMo features
    test_sess = sess.run(tf.reduce_mean(embeddings, 1)) 

test_sess
# Out:
# array([[-0.0823871 ,  0.07898234,  0.08993164, ..., -0.2251663 ,
#          0.05554263,  0.29672712]], dtype=float32)

# %% [markdown]
# 了解 ELMo model 的使用方法後，就可以開始轉換訓練資料了 <br>
#
# 為了避免耗盡運算資源，我們將批次轉換成 ELMo vector

# %%
list_train = [train[i:i+100] for i in range(0,train.shape[0],100)]
# list_test = [test[i:i+100] for i in range(0,test.shape[0],100)]

list_train
# Out:
# [     id  label                                              tweet  \
#  0     1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
#  1     2      0  Finally a transparant silicon case ^^ Thanks t...
#  2     3      0  We love this! Would you go? #talk #makememorie...
#  3     4      0  I'm wired I know I'm George I was made that wa...
#  4     5      1  What amazing service! Apple won't even talk to...
#  5     6      1  iPhone software update fucked up my phone big ...
#  6     7      0  Happy for us .. #instapic #instadaily #us #son...
#  7     8      0  New Type C charger cable #UK http://www.ebay.c...
#  8     9      0  Bout to go shopping again listening to music #...
#  9    10      0  Photo: #fun #selfie #pool #water #sony #camera...
#  10   11      1  hey #apple when you make a new ipod dont make ...
#  11   12      1  Ha! Not heavy machinery but it does what I nee...
#  12   13      1  Contemplating giving in to the iPhone bandwago...
#  13   14      0  I just made another crazy purchase lol my theo...
#  14   15      1  @shaqlockholmes @sam_louise1991 the battery is...
#  15   16      0  From #DeepEllum towards #downtown #Dallas. #Bi...
#  16   17      0  Like and Share if you want this 3D Phone Case ...
#  17   18      0  Go crazy !! #iphonesia, #iphone, #instagood, #...
#  18   19      1  The reason I don't have one. #iphone #suck #ap...
#  19   20      1  How is the apple store gunna be out of 5C scre...
#  20   21      0  #Apple #Art #Easter #Dear #Friends If you woul...
#  21   22      0  Excuse me, waiter?... There seems to be a pie ...
#  22   23      1  I've had this new ipod for four days? And this...
#  23   24      1  when your iPhone screen goes completely black ...
#  24   25      0  It's time for new wallpapers #phone #wallpaper...
#  25   26      0  1.05 billion for 3 patents where there is prio...
#  26   27      1  $&@*# my ipod is all messed up and i haven't d...
#  27   28      1  My ipod touch is frozen on the apple logo when...
#  28   29      0  do love a new phone case! #flower #green #diam...
#  29   30      0  Must watch #youtube #subscribe #daily #vlog #t...
#  ..  ...    ...                                                ...
#  70   71      0  That feeling when your broken phone's screen i...
#  71   72      0  Be the light for my way, please. . . . . . #la...
#  72   73      0  New acquisition #iphone #5s #gold #apple it #p...
#  73   74      1  If i havent texted back my phone reset after w...
#  74   75      0  Happy Sunday! :) #Samsung #phone #smile #incep...
#  75   76      0  #Carcasa clear cover para #Samsung #GrandPrime...
#  76   77      1  Apple's mighty mouse came with 2 lithium AA's....
#  77   78      0  @NycLesbians <<<<< #FollowSunday #FOLLOWBACK #...
#  78   79      0  I’m not happy at all with @SamsungUK @Samsung ...
#  79   80      0  @lilya_0716 Retweet #a7sll #sony #sonya7s2 #th...
#  80   81      1  @CNET call it the Apple Phone and put an absur...
#  81   82      0  Commonwealth Games: Skye Nicolson wins boxing ...
#  82   83      1  Oh dear, no joy for the new iPhone 5! Any good...
#  83   84      0  Love it finally enjoying my game!!!! #ps3 #tom...
#  84   85      0  The Hunger Games In The Simpsons! #simpsons #t...
#  85   86      0  #Apple called and made something wrong, right ...
#  86   87      0  New item @jammieexoxo recommends #iphone #appl...
#  87   88      1  #fuckYou #Apple and your never ending bugs! It...
#  88   89      0  What a cute girlfriend! Happy one year, love y...
#  89   90      0  My birthday present from Mom! #apple #macbookp...
#  90   91      0  Photo: Quote Of The Day #quotes #wisdom #words...
#  91   92      0  @SamsungUK have to applaud #samsung #Sheffield...
#  92   93      1  Just lost everything due to the freaking iphon...
#  93   94      1  @mashable your #Apple #hater #yousuck #brianto...
#  94   95      1  Thanks for working on your servers all day Son...
#  95   96      0  New Models #byhilalak #earphones #urbanears #h...
#  96   97      0  Photo: #iTunes #vicio #nellyfurtado #nelstar #...
#  97   98      0  See how many features you didn't know your iPh...
#  98   99      0  Happiness in a box!!! Yey!!! #me #phone #sony ...
#  99  100      0  #feliz #sábado con #café #saturday with #coffe...
#
#                                            clean_tweet
#  0   fingerprint pregnancy test android app beautif...
#  1   finally a transparant silicon case thank to -P...
#  2   -PRON- love this would -PRON- go talk makememo...
#  3   -PRON- be wired i know -PRON- be george i be m...
#  4   what amazing service apple will not even talk ...
#  5   iphone software update fuck up -PRON- phone bi...
#  6   happy for -PRON- .. instapic instadaily -PRON-...
#  7   new type c charger cable uk … bay amazon etsy ...
#  8   bout to go shop again listen to music iphone j...
#  9   photo fun selfie pool water sony camera picoft...
#  10  hey apple when -PRON- make a new ipod do not m...
#  11  ha not heavy machinery but -PRON- do what i ne...
#  12  contemplate give in to the iphone bandwagon si...
#  13  i just make another crazy purchase lol -PRON- ...
#  14  shaqlockholme samlouise the battery be so pain...
#  15  from deepellum towards downtown dalla . bigd s...
#  16  like and share if -PRON- want this d phone cas...
#  17  go crazy iphonesia , iphone , instagood , inst...
#  18  the reason i do not have one . iphone suck app...
#  19  how be the apple store gunna be out of c scree...
#  20  apple art easter dear friend if -PRON- would l...
#  21  excuse -PRON- , waiter ... there seem to be a ...
#  22  -PRON- have have this new ipod for four day an...
#  23  when -PRON- iphone screen go completely black ...
#  24  -PRON- be time for new wallpaper phone wallpap...
#  25  . billion for patent where there be prior art ...
#  26  -PRON- ipod be all mess up and i have not do n...
#  27  -PRON- ipod touch be freeze on the apple logo ...
#  28  do love a new phone case flower green diamond ...
#  29  must watch youtube subscribe daily vlog twitch...
#  ..                                                ...
#  70  that feel when -PRON- broken phone 's screen b...
#  71  be the light for -PRON- way , please . . . . ....
#  72  new acquisition iphone s gold apple -PRON- pho...
#  73  if i have not texte back -PRON- phone reset af...
#  74  happy sunday samsung phone smile inception whi...
#  75  carcasa clear cover para samsung grandprime fe...
#  76  apple 's mighty mouse come with lithium aa 's ...
#  77  nyclesbian followsunday followback rt teamfoll...
#  78  -PRON- be not happy at all with samsunguk sams...
#  79  lilya retweet a sll sony sonya s throwback sho...
#  80  cnet call -PRON- the apple phone and put an ab...
#  81  commonwealth game skye nicolson win box gold i...
#  82  oh dear , no joy for the new iphone any good c...
#  83  love -PRON- finally enjoy -PRON- game ps tombr...
#  84  the hunger game in the simpson simpson thehung...
#  85  apple call and make something wrong , right to...
#  86  new item jammieexoxo recommend iphone apple ea...
#  87  fuckyou apple and -PRON- never end bug -PRON- ...
#  88  what a cute girlfriend happy one year , love -...
#  89  -PRON- birthday present from mom apple macbook...
#  90  photo quote of the day quote wisdom word smile...
#  91  samsunguk have to applaud samsung sheffield st...
#  92  just lose everything due to the freak iphone u...
#  93  mashable -PRON- apple hater yousuck briantong ...
#  94  thank for work on -PRON- server all day sony ....
#  95  new model byhilalak earphone urbanear handmade...
#  96  photo itune vicio nellyfurtado nelstar playing...
#  97  see how many feature -PRON- do not know -PRON-...
#  98  happiness in a box yey -PRON- phone sony xperi...
#  99  feliz sábado con café saturday with coffee and...
#
#  [100 rows x 4 columns],
#        id  label                                              tweet  \
#  100  101      0  #dreamy effect created straight from the #iPho...
#  101  102      0  Finalllllly my Note 4 is here :) #note4 #samsu...
#  102  103      0  Special App For valentine >> https://itunes.ap...
#  103  104      0  Photo of the Day #36 #Erie #pa #car #sign #ilo...
#  104  105      0  Lunch in the park #apple #carrot #banana and m...
#  105  106      0  Not on my #iPhone--the confession app! When we...
#  106  107      0  Day 32 --- P.S. I Love You ... #iphone #photog...
#  107  108      1  Hey apple I just want to say fuck u and ur new...
#  108  109      0  Photo: #sunset #westcoast #iphone (Taken with ...
#  109  110      0  Just added myself to the http://wefollow.com t...
#  110  111      1  iphones are a $&@*# for losin phone reception,...
#  111  112      0  @TMobile the day has come thanks to #jump I ca...
#  112  113      0  Get a Taste of Frank Ocean’s New… http://dlvr....
#  113  114      1  so annoying when you finish all the levels of ...
#  114  115      0  Nothing you wear is more important than your s...
#  115  116      1  @NatePGilbraith send them as texts. I had to t...
#  116  117      0  fanta #apple #fanta is delish!! #Sunday #sunda...
#  117  118      0  She won't sleep no other way but on my lap #ba...
#  118  119      0  She’s so loverly #tweet #rabbitsofinstagram #b...
#  119  120      0  My new iPhone case~ Happy Valentine's Day :) #...
#  120  121      0  Photo: #vegan #glutenfree #apple #pie #day (at...
#  121  122      1  Technology is so advanced these days but after...
#  122  123      0  Sweet iphone :3 #sweet #phone #iphone #apple #...
#  123  124      0  Wait over.. Finally in hand iPhoneX #iPhoneX #...
#  124  125      0  Unpacking #Sony #Xperia Z5 Compact (#Android)....
#  125  126      1  @MuOneOz Progress bar is 1 car key long. Will ...
#  126  127      0  When Siri doesnt understand commands... lol. #...
#  127  128      0  Endless love #instagram #instagood #instadaily...
#  128  129      1  I will literally cry if I have lost all my con...
#  129  130      0  @andyvaughan - that looks great. i wonder a) w...
#  ..   ...    ...                                                ...
#  170  171      1  #GeniusBar can suck my tubes after my surgery ...
#  171  172      0  I am happy #ps4 #sony #playstation #gta5 #fun ...
#  172  173      1  holy #shitbirds! just watched last night's #co...
#  173  174      0  Book ! #good #night #relax #cool #perfect #boo...
#  174  175      0  Photo: A Prosperous New Year to Everyone!! Wel...
#  175  176      0  Just One More #blog #video #girl #amazing #fas...
#  176  177      1  New iPhone OS on the 3G FUCKING SUCKS. I WANT ...
#  177  178      0  Baby, let my love adorn you... #miguel #fan #a...
#  178  179      0  Photo: 5. Sign: #Peace #Sign #junephotoaday #p...
#  179  180      0  I would just delet all my photos and vids from...
#  180  181      0  @nobauerm - lets get you hooked up, fast. w an...
#  181  182      1  Why does it take me all evening to update two ...
#  182  183      0  #Audi to offer #Apple and #Android smartphone ...
#  183  184      1  Just ran to buy an iPhone charger in the middl...
#  184  185      1  I haven't used an apple product in over a year...
#  185  186      0  Photo: Pic Of The Day #quotes #wisdom #words #...
#  186  187      0  New york baby ;) #new #york #amazing #city #th...
#  187  188      0  CHASING PAVEMENTS "a story about , #friendship...
#  188  189      0  @IrishAzada Do You Love Photography ? Go Follo...
#  189  190      0  Like and Share if you want this Car Accessory ...
#  190  191      1  #Apple, you #suck. Every time you #update your...
#  191  192      0  #goodnight #dubai! Sweet #dreams! #life #hope ...
#  192  193      0  Birthday present came in advance!! Thank you s...
#  193  194      0  #Saturday Everyone! Look in our #shop for #gre...
#  194  195      0  Turkey. #photography #photo #travel #nature #p...
#  195  196      0  Amigos ... Friends ... #iphonesia, #iphone, #i...
#  196  197      0  Things, that make me : #reading. I just my #pi...
#  197  198      0  EDM IS MY LIFE!!! #hardwell #amor #apple #avic...
#  198  199      0  Its been a year and my shuffle on my #Samsung ...
#  199  200      0  thank u so much  #God #Christian #iphone #in...
#
#                                             clean_tweet
#  100  dreamy effect create straight from the iphone ...
#  101  finalllllly -PRON- note be here note samsung g...
#  102  special app for valentine … fashion nowplaye d...
#  103  photo of the day erie pa car sign iloveyou bla...
#  104  lunch in the park apple carrot banana and -PRO...
#  105  not on -PRON- iphonethe confession app when -P...
#  106  day p.s . i love -PRON- ... iphone photography...
#  107  hey apple i just want to say fuck u and ur new...
#  108  photo sunset westcoast iphone take with instag...
#  109  just add -PRON- to the twitt directory under n...
#  110  iphone be a for losin phone reception , get te...
#  111  tmobile the day have come thank to jump i can ...
#  112  get a taste of frank ocean ’s new … news photo...
#  113  so annoying when -PRON- finish all the level o...
#  114  nothing -PRON- wear be more important than -PR...
#  115  natepgilbraith send -PRON- as text . i have to...
#  116  fanta apple fanta be delish sunday sundayfunda...
#  117  -PRON- will not sleep no other way but on -PRO...
#  118  -PRON- ’s so loverly tweet rabbitsofinstagram ...
#  119  -PRON- new iphone case happy valentine 's day ...
#  120  photo vegan glutenfree apple pie day at silly ...
#  121  technology be so advanced these day but after ...
#  122  sweet iphone sweet phone iphone apple candy fu...
#  123  wait over .. finally in hand iphonex iphonex i...
#  124  unpack sony xperia z compact android . really ...
#  125  muoneoz progress bar be car key long . will gi...
#  126  when siri do not understand command ... lol . ...
#  127  endless love instagram instagood instadaily in...
#  128  i will literally cry if i have lose all -PRON-...
#  129  andyvaughan that look great . i wonder a when ...
#  ..                                                 ...
#  170  geniusbar can suck -PRON- tube after -PRON- su...
#  171  i be happy ps sony playstation gta fun design ...
#  172  holy shitbird just watch last night 's colbert...
#  173  book good night relax cool perfect book iphone...
#  174  photo a prosperous new year to everyone welcom...
#  175  just one more blog video girl amazing fashion ...
#  176  new iphone os on the g fucking suck . i want t...
#  177  baby , let -PRON- love adorn -PRON- ... miguel...
#  178  photo . sign peace sign junephotoaday photoada...
#  179  i would just delet all -PRON- photo and vid fr...
#  180  nobauerm let get -PRON- hooked up , fast . w a...
#  181  why do -PRON- take -PRON- all evening to updat...
#  182  audi to offer apple and android smartphone int...
#  183  just run to buy an iphone charger in the middl...
#  184  i have not use an apple product in over a year...
#  185  photo pic of the day quote wisdom word smile f...
#  186  new york baby new york amazing city the big ap...
#  187  chase pavement a story about , friendship , fa...
#  188  irishazada do -PRON- love photography go follo...
#  189  like and share if -PRON- want this car accesso...
#  190  apple , -PRON- suck . every time -PRON- update...
#  191  goodnight dubai sweet dream life hope joy duba...
#  192  birthday present come in advance thank -PRON- ...
#  193  saturday everyone look in -PRON- shop for grea...
#  194  turkey . photography photo travel nature photo...
#  195  amigos ... friend ... iphonesia , iphone , ins...
#  196  thing , that make -PRON- read . i just -PRON- ...
#  197  edm be -PRON- life hardwell amor apple avicii ...
#  198  -PRON- be a year and -PRON- shuffle on -PRON- ...
#  199  thank u so much  god christian iphone instag...
#
#  [100 rows x 4 columns],
#        id  label                                              tweet  \
#  200  201      0  Woohoo! Finally i get my NX1000 #finally #came...
#  201  202      0  Family #family #friends #beauty #fun #cuties #...
#  202  203      0  Happy my #Samsung #Galaxy #Note2 got updated w...
#  203  204      0  RT @SleekDeals: Hot Deal! High Tech Lightning ...
#  204  205      0  IN LOOOVE #amazing #beautiful #copenhagen #cre...
#  205  206      0  Too bad @sprint doesn't carry any #lumia devic...
#  206  207      0  We would like to wish you an amazing day! Make...
#  207  208      0  My iPads new home :) #ipad #leopardprint #neon...
#  208  209      0  my #iPhone #apps I can listen to drive time hi...
#  209  210      1  #dissatisfied #Apple #iPhone6sPlus Not for run...
#  210  211      0  he loves the fuck outta me. @kingponder6 #$&@*...
#  211  212      0  She is as ready as i am to do this! #chromeboo...
#  212  213      0  Beach group text. #beach #ocean #cellphone #fr...
#  213  214      0  At last I have my #apple watch 42mm space blac...
#  214  215      0  I (L) NY :). #hug #follow #like #iphone #tatto...
#  215  216      1  @SLICK1913 @mindy0x id totally fuck siri her k...
#  216  217      0  Lol I love my Iphone Rt:TO #Apple who fuckedUP...
#  217  218      0  Photo: My new MacBook air is installed and rea...
#  218  219      0  Throw your worries be fit and fab! #marjdiary ...
#  219  220      0  Samsung Galaxy S9+ Plus Dual Sim G965FD 6GB RA...
#  220  221      0  New phone...... Yes please :) been without a p...
#  221  222      0  speed wifi+3G+4G 2016 https://goo.gl/qMdlXQ #a...
#  222  223      0  219€99 Samsung gear s2 Etat: comme neuve #Sams...
#  223  224      1  @applenws my #iphone but why would you trade a...
#  224  225      1  Mac OS http://Mail.app on Hight Sierra is a bu...
#  225  226      1  Why when i send a calendar event invite to a e...
#  226  227      0  I like iphone only because I get to play games...
#  227  228      0  My phone keeps freezing whenever i go to end a...
#  228  229      1  Ever since I updated my phone. It's been fucki...
#  229  230      0  #Chicwithatwist TEAM #ootd #mixandmatch #urban...
#  ..   ...    ...                                                ...
#  270  271      0  Haven't tried Instagram yet? Here's some reaso...
#  271  272      0  Too #delicious !! #morning #friday #smoothie #...
#  272  273      0  you don't have to wait to long for another app...
#  273  274      0  Reflect #iphonesia #iphone #instagood #instagr...
#  274  275      0  Hi to my new phone cover! :) #ebay #blue #towe...
#  275  276      0  Alternative Power Fix for #Apple Cinema Displa...
#  276  277      0  New phone. #iphone #iphone6 #new #phone #mine ...
#  277  278      0  Thanks @OnePlus_DE @oneplus for still providin...
#  278  279      0  The #iphone doesn't seem to have a #confederat...
#  279  280      0  Photo: The new addition to our family! #instap...
#  280  281      1  Fucking apple man I just wanna use m wifi and ...
#  281  282      0  Take a look at Samsung's cool "I see your drea...
#  282  283      1  1 hour usage and phones down 13% ... Thanks #i...
#  283  284      1  Tablets using Google's Android system accounte...
#  284  285      1  downgraded my phone, but backups aren't compat...
#  285  286      1  ...and spell check if I mistyped "quickest" ho...
#  286  287      1  Dude this is the 4th usb chord thats broken in...
#  287  288      0  One of my newest #models - #iphone #iphoneogra...
#  288  289      0  #new #samsung #galaxy #advance #case #I #get #...
#  289  290      0  Yey! Thanks dad. :) #xperia #sony #z2 #xperiaz...
#  290  291      0  Follow @capetownsup on Instagram http://mf.tt/...
#  291  292      1  Anyone else having trouble with #iPhone update...
#  292  293      0  Gain Followers RT This MUST FOLLOW ME I FOLLOW...
#  293  294      0  Welcome to my world, iPhone 6 =] #iphone6 #iph...
#  294  295      1  Why can't an iPhone block numbers which call e...
#  295  296      1  Hey @APPLEOFFIClAL, why do we schedule appts i...
#  296  297      0  Uninstall #Samsung Kies to get #Android File T...
#  297  298      0  Gain Followers RT This MUST FOLLOW ME I FOLLOW...
#  298  299      0  Photo: #yea #bro #fifa #all #day #dope #iphone...
#  299  300      0  finally we get something from #apple the ameri...
#
#                                             clean_tweet
#  200  woohoo finally i get -PRON- nx finally camera ...
#  201  family family friend beauty fun cutie iphone i...
#  202  happy -PRON- samsung galaxy note get update wi...
#  203  rt sleekdeal hot deal high tech lightning to u...
#  204  in looove amazing beautiful copenhagen creativ...
#  205  too bad sprint do not carry any lumia device b...
#  206  -PRON- would like to wish -PRON- an amazing da...
#  207  -PRON- ipad new home ipad leopardprint neon ip...
#  208  -PRON- iphone app i can listen to drive time h...
#  209  dissatisfy apple iphone splus not for runner ,...
#  210  -PRON- love the fuck outta -PRON- . kingponder...
#  211  -PRON- be as ready as i be to do this chromebo...
#  212  beach group text . beach ocean cellphone frien...
#  213  at last i have -PRON- apple watch mm space bla...
#  214  i l ny . hug follow like iphone tattoo christm...
#  215  slick mindy x -PRON- would totally fuck siri -...
#  216  lol i love -PRON- iphone rtto apple who fucked...
#  217  photo -PRON- new macbook air be instal and rea...
#  218  throw -PRON- worry be fit and fab marjdiary sa...
#  219  samsung galaxy s plus dual sim g fd gb ram b b...
#  220  new phone ...... yes please be without a phone...
#  221  speed wifi g g android app unitedstate cute co...
#  222  € samsung gear s etat comme neuve samsung gear...
#  223  applenws -PRON- iphone but why would -PRON- tr...
#  224  mac os on hight sierra be a buggy little crap ...
#  225  why when i send a calendar event invite to a e...
#  226  i like iphone only because i get to play game ...
#  227  -PRON- phone keep freeze whenever i go to end ...
#  228  ever since i update -PRON- phone . -PRON- be b...
#  229  chicwithatwist team ootd mixandmatch urban sty...
#  ..                                                 ...
#  270  have not try instagram yet here be some reason...
#  271  too delicious morning friday smoothie nutribul...
#  272  -PRON- do not have to wait to long for another...
#  273  reflect iphonesia iphone instagood instagram p...
#  274  hi to -PRON- new phone cover ebay blue tower s...
#  275  alternative power fix for apple cinema display...
#  276  new phone . iphone iphone new phone mine silve...
#  277  thank oneplusde oneplus for still provide upda...
#  278  the iphone do not seem to have a confederate f...
#  279  photo the new addition to -PRON- family instap...
#  280  fuck apple man i just wanna use m wifi and -PR...
#  281  take a look at samsung 's cool i see -PRON- dr...
#  282   hour usage and phone down ... thank iphone apple
#  283  tablet use google 's android system account fo...
#  284  downgrade -PRON- phone , but backup be not com...
#  285  ... and spell check if i mistype quick how can...
#  286  dude this be the th usb chord that s break in ...
#  287  one of -PRON- new model iphone iphoneography t...
#  288  new samsung galaxy advance case i get -PRON- f...
#  289  yey thank dad . xperia sony z xperiaz gift gra...
#  290  follow capetownsup on instagram sup surf fun c...
#  291  anyone else have trouble with iphone update -P...
#  292  gain follower rt this must follow -PRON- i fol...
#  293  welcome to -PRON- world , iphone iphone iphone...
#  294  why can not an iphone block number which call ...
#  295  hey appleofficlal , why do -PRON- schedule app...
#  296  uninstall samsung ky to get android file trans...
#  297  gain follower rt this must follow -PRON- i fol...
#  298  photo yea bro fifa all day dope iphone instago...
#  299  finally -PRON- get something from apple the am...
#
#  [100 rows x 4 columns],
#        id  label                                              tweet  \
#  300  301      0  Fibs rhymes with Sibs, Nibs, Jibs, Bibs, Ribs,...
#  301  302      0  #OnePlus5 finally fixed, so fast, so efficient...
#  302  303      1  Thought it would be fun to jailbreak my iPod n...
#  303  304      0  Love my fucking iPad!!! #rednose #musicevideo ...
#  304  305      1  Why do people with iPhones have to keep showin...
#  305  306      0  Follow @capetownsup on Instagram http://mf.tt/...
#  306  307      0  Photo: Meanwhile in twitter… #Samsung #GalaxyP...
#  307  308      0  @SamsungMobileUS honored me for using $5 in my...
#  308  309      0  Happy Mother's Day #mom #mothersday #iphone #i...
#  309  310      0  RT @LoriMoreno: I'm married, but here you go! ...
#  310  311      0  Follow @capetownsup on Instagram http://mf.tt/...
#  311  312      1  WHY CANT IPHONES HAVE THE OPTION TO CHANGE THE...
#  312  313      0  Using & LOVING! Instagram Upgrade Introduces a...
#  313  314      0  Apple Iphone X #apple #iphonex #techjunkie #te...
#  314  315      0  Only reason I'd get an iPhone is b/c of all th...
#  315  316      0  Solid Gold retro Christmas [video] http://tiny...
#  316  317      1  Yes! Finally got the #nougat update on my #sam...
#  317  318      0  Unboxing my new smartphone #op2 #oneplus2 #one...
#  318  319      0  My small garden — Steemit https://steemit.com/...
#  319  320      0  New video #youtube #subscribe #daily #vlogs #t...
#  320  321      1  Hate how my phone has an iPod in it, it takes ...
#  321  322      0  New one...Yey!!! #babypink #pink #otterbox #sa...
#  322  323      0  We would like to wish you an amazing day! Make...
#  323  324      0  Under water #summer #summertime #pool #country...
#  324  325      0  I'm trying, $&@*# it I am. #instagram #iphone4...
#  325  326      0  First Yellow — Steemit https://steemit.com/pho...
#  326  327      0  Be Good To Your Woman Our She Might Do This #i...
#  327  328      1  Anyone know why my ipod WON'T turn on? I tried...
#  328  329      0  munchhhhhh #chocolate #instagood #iphoneonly #...
#  329  330      0  Tell us what you about #SupaCamX, the amazing ...
#  ..   ...    ...                                                ...
#  370  371      1  Phone freaked and now I have no pictures or an...
#  371  372      0  Gain Followers RT This MUST FOLLOW ME I FOLLOW...
#  372  373      0  #iPhone 6 #PriceReduction With #TouchID & 4G N...
#  373  374      0  So excited for this little arrival today! @Sam...
#  374  375      1  iPhone and iTunes pissing me off? Might as wel...
#  375  376      0  Happy Friday! Here is the sticker app preview ...
#  376  377      1  And finally the iPhone shatters 1 month before...
#  377  378      0  furr.tree #nyc #ny #vscocam #vsco #sony #sonya...
#  378  379      0  #Roast #Pork, most definately with #Apple #Sau...
#  379  380      0  Who are you waiting for ? #wait #you #cute #af...
#  380  381      0  Brad Boxberger nearing return to Rays #news #p...
#  381  382      0  Pretty amazing feeling having a phone that doe...
#  382  383      0  How good is this?? #free #fruit at #woolies #w...
#  383  384      0  And #Apple brings out more things I want, of c...
#  384  385      0  Happiness make you better person #kiss #girl #...
#  385  386      0  Cute Hearts?! Custom #iPad and #iPhone case fo...
#  386  387      0  A #refreshing #fresh #salad is all it takes to...
#  387  388      0  with my iPhone 8 Plus | “The #iPhoneX Is A Use...
#  388  389      0  In My Library: Paula Vogel #news #photography ...
#  389  390      0  Say hello to my new camera! The Sony FS7! #vid...
#  390  391      0  Be Happy :) #fit #style #friday #money #samsun...
#  391  392      0  #moschino #iphone #case my new baby #inspired ...
#  392  393      0  #Black #outing #wednesday #be #dont #think #ba...
#  393  394      0  10Pcs Exquisite Squishy Random Charm in http:/...
#  394  395      0  iPhone 16...? #iPhone #Apple #avtweeps #AVTwee...
#  395  396      0  Gain Followers RT This MUST FOLLOW ME I FOLLOW...
#  396  397      0  we are loving #Cake day in #Brighton! got some...
#  397  398      0  New tv in bedroom so happy #samsung #smart #tv...
#  398  399      0  Last day to vote for dabball this round. http:...
#  399  400      0  I absolutely love Sony music Cam. I recommend!...
#
#                                             clean_tweet
#  300  fibs rhyme with sibs , nibs , jibs , bibs , ri...
#  301  oneplus finally fix , so fast , so efficient t...
#  302  think -PRON- would be fun to jailbreak -PRON- ...
#  303  love -PRON- fuck ipad rednose musicevideo blac...
#  304  why do people with iphone have to keep show -P...
#  305  follow capetownsup on instagram sup surf fun c...
#  306  photo meanwhile in twitt … samsung galaxypocke...
#  307  samsungmobileus honor -PRON- for use in -PRON-...
#  308  happy mother 's day mom mothersday iphone igda...
#  309  rt lorimoreno -PRON- be married , but here -PR...
#  310  follow capetownsup on instagram sup surf fun c...
#  311  why can not iphone have the option to change t...
#  312  use love instagram upgrade introduce a powerfu...
#  313  apple iphone x apple iphonex techjunkie tech i...
#  314  only reason -PRON- would get an iphone be bc o...
#  315  solid gold retro christmas video ff friend gra...
#  316  yes finally get the nougat update on -PRON- sa...
#  317  unbox -PRON- new smartphone op oneplus oneplus...
#  318  -PRON- small garden — steemit … small garden h...
#  319  new video youtube subscribe daily vlog twitch ...
#  320  hate how -PRON- phone have an ipod in -PRON- ,...
#  321  new one ... yey babypink pink otterbox samsung...
#  322  -PRON- would like to wish -PRON- an amazing da...
#  323  under water summer summertime pool countryhous...
#  324  -PRON- be try , -PRON- i be . instagram iphone...
#  325  first yellow — steemit … yellow nature color c...
#  326  be good to -PRON- woman -PRON- -PRON- may do t...
#  327  anyone know why -PRON- ipod will not turn on i...
#  328  munchhhhhh chocolate instagood iphoneonly ipho...
#  329  tell -PRON- what -PRON- about supacamx , the a...
#  ..                                                 ...
#  370  phone freak and now i have no picture or any o...
#  371  gain follower rt this must follow -PRON- i fol...
#  372  iphone pricereduction with touchid g nfc conta...
#  373  so excited for this little arrival today samsu...
#  374  iphone and itune piss -PRON- off may as well j...
#  375  happy friday here be the sticker app preview a...
#  376  and finally the iphone shatter month before -P...
#  377  furr.tree nyc ny vscocam vsco sony sonyalpha a...
#  378  roast pork , most definately with apple sauce ...
#  379  who be -PRON- wait for wait -PRON- cute aftern...
#  380  brad boxberger near return to ray news photogr...
#  381  pretty amazing feeling have a phone that do no...
#  382  how good be this free fruit at woolie woolwort...
#  383  and apple bring out more thing i want , of cou...
#  384  happiness make -PRON- well person kiss girl pi...
#  385  cute heart custom ipad and iphone case for the...
#  386  a refreshing fresh salad be all -PRON- take to...
#  387  with -PRON- iphone plus " the iphonex be a use...
#  388  in -PRON- library paula vogel news photography...
#  389  say hello to -PRON- new camera the sony fs vid...
#  390  be happy fit style friday money samsung wel ös...
#  391  moschino iphone case -PRON- new baby inspire i...
#  392  black outing wednesday be do not think bad gam...
#  393  pcs exquisite squishy random charm in iphone s...
#  394  iphone ... iphone apple avtweep avtweetup hot ...
#  395  gain follower rt this must follow -PRON- i fol...
#  396  -PRON- be love cake day in brighton get some p...
#  397    new tv in bedroom so happy samsung smart tv new
#  398  last day to vote for dabball this round . art ...
#  399  i absolutely love sony music cam . i recommend...
#
#  [100 rows x 4 columns],
#        id  label                                              tweet  \
#  400  401      1  Don't get why iPhone's are popular, they're pu...
#  401  402      1  I hate iPhones. Why is it impossible for them ...
#  402  403      1  #hateapple update didn't work causing my compu...
#  403  404      1  Scrolls through twitter and Facebook for like ...
#  404  405      0  I came home to my Mac case being at the front ...
#  405  406      0  Just installed icloud on my computer and it ha...
#  406  407      0  Coming Soon! Human Hues Apparel! #humanity #go...
#  407  408      1  Seriously. Migration assistant IS NOT seamless...
#  408  409      0  Gain Followers RT This MUST FOLLOW ME I FOLLOW...
#  409  410      0  Follow @capetownsup on Instagram http://mf.tt/...
#  410  411      1  Why does the word #fuck STILL turn to #duck in...
#  411  412      0  #just the #wind in the #trees #haveaniceday / ...
#  412  413      0  #sunflowers make me #nature #flower #sunflower...
#  413  414      0  Razr d3 #new #estreno #motorola #razr #razrd3 ...
#  414  415      0  The iPhone 6S is Totally Amazing!! #iPhone #iO...
#  415  416      1  “@drshwetapuri: 'Apple working on iPhone 6 run...
#  416  417      0  I love You #bff #friend ##me #brazilian #cute ...
#  417  418      0  WARNING - Do not poke the sleeping giant http:...
#  418  419      0  New lock screen and home screen! Hehe #lockscr...
#  419  420      0  Great. More pointless apps I don't even want t...
#  420  421      0  drinking coffee! reading from http://bit.ly/si...
#  421  422      0  Aww thank you so much! "@Ms_Harlem: #NOWPLAYIN...
#  422  423      1  @applenws #apple your shitty IOS 6 made everyo...
#  423  424      0  Good to have my tab back after 2 weeks #samsun...
#  424  425      0  #hateapple just wasted 3.5 hours of my life pa...
#  425  426      0  I going to my back #iPhone and seeing more #fu...
#  426  427      0  New hoesje #samsung #galaxy #s #lll #vistaprin...
#  427  428      0  ༺☾➊☽༻ RETWEET ༺☾➋☽༻ FOLLOW ALL WHO RT ༺☾➌☽༻ FO...
#  428  429      0  #its #me #Nickii #orange #pictureoftheday #sam...
#  429  430      1  I swear to god I'm going to throw my phone und...
#  ..   ...    ...                                                ...
#  470  471      0  @Rings_of_Kerry get the #samsunggalaxys3 it la...
#  471  472      0  The @APPLEOFFIClAL geniuses asked me, "Is ever...
#  472  473      0  Meet Sony's Newest Employee. #sony #newjob #sm...
#  473  474      0  How to Pronounce Generic Mexican ↺RT http://ww...
#  474  475      0  https://spark.adobe.com/post/yLd8LIEaO1I6v/?w=...
#  475  476      0  Is #Beats a #Mistake for #Apple?►http://money....
#  476  477      0  My birthday gift from my aunt I'm so so so hap...
#  477  478      0  #Audio Proverbs #app: English-Italian; Listen,...
#  478  479      1  yeah so I should have iOS7 soon then? @badbadn...
#  479  480      0  #Early #Christmas #gift from my #sweet #husban...
#  480  481      0  Haha :) #instapic #kmrpocket #sony #scholl #fr...
#  481  482      0  problems with #Samsung #Galaxy and #Froyo? wel...
#  482  483      1  i fu**ing hate #iTunes 10-it $&@*# screwed my ...
#  483  484      0  Heads Hop! New game coming soon... #news #gami...
#  484  485      1  Second time this week I want to get rid of my ...
#  485  486      0  Photo: Quote Of The Day #quotes #wisdom #words...
#  486  487      0  Finally a Milanese Loop. #watch #apple #watch ...
#  487  488      0  ? Aka #forrealdoe workout? Or train? #Geefilmw...
#  488  489      0  @BMarie_23 <<<<< #FollowSunday #FOLLOWBACK #RT...
#  489  490      0  Makeup Show NYC #NYC #makeup #instagram #iphon...
#  490  491      1  anyone who updated to iOS7 knows the pain I ha...
#  491  492      0  Tan check. #tan #spring #april # #fuckyou #dop...
#  492  493      0  Gain Followers RT This MUST FOLLOW ME I FOLLOW...
#  493  494      0  One Love #photgraphy #Sony #xperiaz3 #Selfie #...
#  494  495      0  Photo of the day #sun #nikon #apple #iphone #p...
#  495  496      1  Why are you deleting all my emails you $&@*# u...
#  496  497      0  My boyfriend new song #InstaSize #iPhone #lol ...
#  497  498      0  Samsung Engineering building~! #PhotoOfTheWeek...
#  498  499      0  RT cook_jk2 cook_jk2 #未熟な料理 #食材の全てに感謝 #cooking...
#  499  500      0  shopping day #me #starbucks #coffee #like4like...
#
#                                             clean_tweet
#  400  do not get why iphone 's be popular , -PRON- b...
#  401  i hate iphone . why be -PRON- impossible for -...
#  402  hateapple update do not work cause -PRON- comp...
#  403  scroll through twitter and facebook for like m...
#  404  i come home to -PRON- mac case be at the front...
#  405  just instal icloud on -PRON- computer and -PRO...
#  406  come soon human hue apparel humanity goodvibe ...
#  407  seriously . migration assistant be not seamles...
#  408  gain follower rt this must follow -PRON- i fol...
#  409  follow capetownsup on instagram sup surf fun c...
#  410  why do the word fuck still turn to duck in -PR...
#  411  just the wind in the tree haveaniceday french ...
#  412  sunflower make -PRON- nature flower sunflower ...
#  413  razr d new estreno motorola razr razrd felicid...
#  414  the iphone s be totally amazing iphone io appl...
#  415  " drshwetapuri ' apple work on iphone run on i...
#  416  i love -PRON- bff friend -PRON- brazilian cute...
#  417  warning do not poke the sleep giant … cute aww...
#  418  new lock screen and home screen hehe lockscree...
#  419  great . more pointless app i do not even want ...
#  420  drink coffee reading from free iphone app beca...
#  421  aww thank -PRON- so much msharlem nowplaying w...
#  422  applenws apple -PRON- shitty ios make everyone...
#  423  good to have -PRON- tab back after week samsun...
#  424  hateapple just waste . hour of -PRON- life pay...
#  425  i go to -PRON- back iphone and see more fund h...
#  426  new hoesje samsung galaxy s lll vistaprint aff...
#  427  ༺ ☾ ➊ ☽ ༻ retweet ༺ ☾ ➋ ☽ ༻ follow all who rt ...
#  428  -PRON- -PRON- nickii orange pictureoftheday sa...
#  429  i swear to god -PRON- be go to throw -PRON- ph...
#  ..                                                 ...
#  470  ringsofkerry get the samsunggalaxys -PRON- las...
#  471  the appleofficlal genius ask -PRON- , be every...
#  472  meet sony 's new employee . sony newjob smile ...
#  473  how to pronounce generic mexican ↺ rt tothemax...
#  474  … link in bio . off all apparel . of everythin...
#  475  be beat a mistake for apple ► … ► answer no . ...
#  476  -PRON- birthday gift from -PRON- aunt -PRON- b...
#  477  audio proverb app englishitalian listen , repe...
#  478  yeah so i should have io soon then badbadnotgo...
#  479  early christmas gift from -PRON- sweet husband...
#  480  haha instapic kmrpocket sony scholl freecllas ...
#  481  problem with samsung galaxy and froyo well , l...
#  482  i fue hate itune -PRON- screw -PRON- display d...
#  483  head hop new game come soon ... news gaming ga...
#  484  second time this week i want to get rid of -PR...
#  485  photo quote of the day quote wisdom word smile...
#  486  finally a milanese loop . watch apple watch te...
#  487  aka forrealdoe workout or train geefilmworkz g...
#  488  bmarie followsunday followback rt teamfollowba...
#  489  makeup show nyc nyc makeup instagram iphone ip...
#  490  anyone who update to ios know the pain i have ...
#  491  tan check . tan spring april fuckyou dope sick...
#  492  gain follower rt this must follow -PRON- i fol...
#  493  one love photgraphy sony xperiaz selfie mylove...
#  494  photo of the day sun nikon apple iphone photo ...
#  495  why be -PRON- delete all -PRON- email -PRON- u...
#  496  -PRON- boyfriend new song instasize iphone lol...
#  497  samsung engineering building photooftheweek we...
#  498  rt cookjk cookjk 未熟な料理 食材の全てに感謝 cook jk japan ...
#  499  shopping day -PRON- starbuck coffee like like ...
#
#  [100 rows x 4 columns],
#        id  label                                              tweet  \
#  500  501      0  Set up almost done :)) #NewTv #Samsung #Black ...
#  501  502      1  The main reason why I #hateApple is the IOS bu...
#  502  503      0  How do you catch up with your family....? #sou...
#  503  504      1  Even if it was just a picture of an apple. #ap...
#  504  505      0  New cases hanogramcase martyarchs #cases #name...
#  505  506      0  @architecture_3design - TAG YOUR FRIENDS @arch...
#  506  507      1  Iphone 5 is just like the 4s but thinner and h...
#  507  508      1  $&@*# you Apple. $&@*# you. #applesucks #apple...
#  508  509      1  I should be getting my galaxy this week! Yipee...
#  509  510      1  @KateWhinesAlot I do love my ipod I only avoid...
#  510  511      0  Bye bye #Samsung it's time for #SonyXperiaC #w...
#  511  512      1  Android taking a $&@*# on apple, and rightly s...
#  512  513      0  Hard at work doing a word search. #applebees #...
#  513  514      0  Amazon Prime Day 2018: Everything you need to ...
#  514  515      0  Just lost all my numbers and photos of my phon...
#  515  516      1  #fuckyou #apple for not connecting me to iTune...
#  516  517      0  In love with this bathroom #sohohouseberlin #s...
#  517  518      1  @creativestore Cheers! ordered the bluetooth b...
#  518  519      0  Holy crap. The more I look at the new iPhone, ...
#  519  520      0  #iPhone 7 6 and 5 #Samsung S7 S6 S5 and S4 #Ph...
#  520  521      0  We are all ONE human Family #pakistan #humanri...
#  521  522      0  Periwinkle Blue Wooden Bird Feeder - Gardening...
#  522  523      0  Free tablet today. #winning #SundayFunday #Sam...
#  523  524      0  Came home to a new 55 inch flat screen tv! #dr...
#  524  525      0  @_mayralovee @PacTaughtMe We would to be your ...
#  525  526      0  I'm a happy girl :) #GalaxyS4 #TeamGalaxy #Tea...
#  526  527      0  Back in service :) #gayboy #gayguy #enamorado ...
#  527  528      0  Man #apple and @iTunes be on some serious $&@*...
#  528  529      0  Photo: The incredible @teighlorkearney #pretty...
#  529  530      0  I must go out some job done & 2 spread happine...
#  ..   ...    ...                                                ...
#  570  571      1  @AliciaMamo1 how did you manage that?! I dropp...
#  571  572      1  Fucking hate #Apple . Like thanks for deleting...
#  572  573      0  Follow @capetownsup on Instagram http://mf.tt/...
#  573  574      0  Lesson #2 | how to download fonts free on iOS ...
#  574  575      0  Izzi Orbit for the iPhone 5 delivers top notch...
#  575  576      0  An awesome phablet ... note 5 duos. #Note7 not...
#  576  577      0  Photo: I could just #linger for #days and #mel...
#  577  578      1  Samsung Chief Mobile DJ Koh!!! my trade in-pho...
#  578  579      1  The new Apple app on the iPhone keeps crashing...
#  579  580      0  Well, it took time to arrive, but I am very mu...
#  580  581      0  #Little #Robin #hatched over #Easter ! #Monday...
#  581  582      0  Love really does make you do silly things! htt...
#  582  583      0  : English-#Portuguese Audio Proverbs #app just...
#  583  584      0  My New baby #ps4 #gaymer #micromania #destiny ...
#  584  585      0  When you have the #iPhoneX and a #lifeproof ca...
#  585  586      0  Follow @capetownsup on Instagram http://mf.tt/...
#  586  587      0  I got pocket full of happiness to capture ♪ #e...
#  587  588      0  I think I'm gonna delete some pic from my phon...
#  588  589      0  We are happy to announce 10% OFF on our Entire...
#  589  590      0  Designed by Apple in California. #iPhoneX #App...
#  590  591      0  there is a scary connection between a guy and ...
#  591  592      1  @MarketingUK Thnx for your email today!any cha...
#  592  593      1  Finally managed to get a new battery for my ph...
#  593  594      0  Teresa Giudice Heads Back To Court… http://dlv...
#  594  595      0  Finally part of the #iphonegang! #iphone5c #ip...
#  595  596      1  #Sony from the bottom of my heart I would like...
#  596  597      0  #firstpresent from my #firstlove #dating #peng...
#  597  598      0  Look at what I got today #dying #Samsung #s5 #...
#  598  599      1  #HateApple Music. Whether I download music, im...
#  599  600      1  @ScottIwata so what you're saying is, people s...
#
#                                             clean_tweet
#  500       set up almost do newtv samsung black massive
#  501  the main reason why i hateapple be the ios bul...
#  502  how do -PRON- catch up with -PRON- family .......
#  503  even if -PRON- be just a picture of an apple ....
#  504  new case hanogramcase martyarchs case name iph...
#  505  architecture design tag -PRON- friend architec...
#  506  iphone be just like the s but thinner and have...
#  507  -PRON- apple . -PRON- . applesuck apple appleh...
#  508  i should be get -PRON- galaxy this week yipeee...
#  509  katewhinesalot i do love -PRON- ipod i only av...
#  510  bye bye samsung -PRON- be time for sonyxperiac...
#  511  android take a on apple , and rightly so iphon...
#  512  hard at work do a word search . applebee dinne...
#  513  amazon prime day everything -PRON- need to kno...
#  514  just lose all -PRON- number and photo of -PRON...
#  515  fuckyou apple for not connect -PRON- to itune ...
#  516  in love with this bathroom sohohouseberlin son...
#  517  creativestore cheer order the bluetooth bundle...
#  518  holy crap . the more i look at the new iphone ...
#  519  iphone and samsung s s s and s phone by everlu...
#  520  -PRON- be all one human family pakistan humanr...
#  521  periwinkle blue wooden bird feeder garden gift...
#  522  free tablet today . win sundayfunday samsung t...
#  523  come home to a new inch flat screen tv dreamhu...
#  524  mayralovee pactaughtme -PRON- would to be -PRO...
#  525  -PRON- be a happy girl galaxys teamgalaxy team...
#  526  back in service gayboy gayguy enamorado gayman...
#  527  man apple and itune be on some serious .. do n...
#  528  photo the incredible teighlorkearney pretty cu...
#  529  i must go out some job do spread happiness , i...
#  ..                                                 ...
#  570  aliciamamo how do -PRON- manage that i drop -P...
#  571  fuck hate apple . like thank for delete all -P...
#  572  follow capetownsup on instagram sup surf fun c...
#  573  lesson how to download font free on io to desi...
#  574  izzi orbit for the iphone deliver top notch ph...
#  575  an awesome phablet ... note duo . note note .....
#  576  photo i could just linger for day and melt wit...
#  577  samsung chief mobile dj koh -PRON- trade inpho...
#  578  the new apple app on the iphone keep crash and...
#  579  well , -PRON- take time to arrive , but i be v...
#  580  little robin hatch over easter monday use a so...
#  581  love really do make -PRON- do silly thing ipho...
#  582  englishportuguese audio proverb app just relea...
#  583  -PRON- new baby ps gaymer micromania destiny p...
#  584  when -PRON- have the iphonex and a lifeproof c...
#  585  follow capetownsup on instagram sup surf fun c...
#  586  i get pocket full of happiness to capture ♪ ex...
#  587  i think -PRON- be go to delete some pic from -...
#  588  -PRON- be happy to announce off on -PRON- enti...
#  589  design by apple in california . iphonex apple ...
#  590  there be a scary connection between a guy and ...
#  591  marketinguk thnx for -PRON- email todayany cha...
#  592  finally manage to get a new battery for -PRON-...
#  593  teresa giudice head back to court … news photo...
#  594  finally part of the iphonegang iphone c iphone...
#  595  sony from the bottom of -PRON- heart i would l...
#  596  firstpresent from -PRON- firstlove date pengui...
#  597       look at what i get today die samsung s phone
#  598  hateapple music . whether i download music , i...
# ...
#  7782  7783      0  I knew it! #Apple new #iPhone 7S #commercial w...
#  7783  7784      0  I'm in love with my new mobile <3 #Sony #Xperi...
#  7784  7785      0  Crazy kid, always getting into something #inst...
#  7785  7786      1  O I forgot, you can't use the iTunes Store in ...
#  7786  7787      0  #Pie makes everybody makes everybody a poet Yo...
#  7787  7788      0  So true. Plus when I changed from Macbook Pro ...
#  7788  7789      0  claim YOUR fame at http://www.GOOGLEBRITY.com ...
#  7789  7790      0  WHY WILL ITUNES NOT LET ME ADD ANY MUSIC INTO ...
#  7790  7791      1  Hey audiophiles, any of you have or have used ...
#  7791  7792      0  Sunset Today in Zeeland ;-) Samsung Mobile S4 ...
#  7792  7793      0  @Sweetjacinta Smiles... Hey sugar... I already...
#  7793  7794      1  The #rumours are #FALSE. The new #iPhone doesn...
#  7794  7795      1  Nice going #Apple #iPhone update 2 fix locked ...
#  7795  7796      0  Free #Lord #Rangoli https://itunes.apple.com/u...
#  7796  7797      1  If I didn't have an iPhone I'd be asleep every...
#  7797  7798      0  #Apple will be rolling out the #Verizon #iPhon...
#  7798  7799      0  Now between my asthma & allergies, I have no v...
#  7799  7800      0  #Microsoft Windows 10’s privacy policy is new ...
#
#                                              clean_tweet
#  7700  what the duck have sod apple do to -PRON- ipho...
#  7701  hate -PRON- iphone gs right now . i can not ev...
#  7702  samsung have the bad customer service of any c...
#  7703  lightroom by ig notthreeten new year newyear w...
#  7704  proofjalenmcmillan proof of concept for the tr...
#  7705  hahahaaa that face make -PRON- laugh a lot dog...
#  7706  sony xperia z unbox newphone freeupgrade sony ...
#  7707  ipod delete of -PRON- spanish music . but -PRO...
#  7708  love -PRON- instagram instapic instashoot inst...
#  7709  topplepassel followsunday followback rt teamfo...
#  7710  ps gamer gaming finally get one aha hahahah gi...
#  7711  morning light over simone . -PRON- first photo...
#  7712  apple 's io . . update be cause huge battery l...
#  7713  as right now -PRON- be at the apple store and ...
#  7714  friend retrieve message android app beautiful ...
#  7715  birthday to -PRON- . quality team samsung gala...
#  7716  repent rhyme with e , bing , sing , ring , pin...
#  7717  what the actual fuck -PRON- update the faceboo...
#  7718  this accessory ' be the iphone charger . apple...
#  7719  i love -PRON- new camera . the moon moon samsu...
#  7720  the control to -PRON- new tv smarttv sony gift...
#  7721  the view . . . travel traveldiarie travelphoto...
#  7722  photo styledirt instamood instagram iphone liv...
#  7723  platform panic … андроид android game news ios...
#  7724  -PRON- would like to wish -PRON- an amazing da...
#  7725  for beautiful eye , look for the good in other...
#  7726  bw love moment lol lol blackandwhite bw amazin...
#  7727  how could i want more picoftheday pictureofthe...
#  7728  early birthday gift thank -PRON- eat .. -PRON-...
#  7729  have not have a phone for about hour now and i...
#  ...                                                 ...
#  7770  lmao siri iphone s iphone apple funny lol this...
#  7771  all black v wale second test … news photograph...
#  7772  -PRON- mouse memory mouse apple desk lifestyle...
#  7773  -PRON- loathing of apple have multiply to apoc...
#  7774  if i do not come off hold soon , -PRON- be go ...
#  7775  -PRON- phone be fuck will let -PRON- type on f...
#  7776  closed vocation newyear trip thailand khaoko a...
#  7777  just add thermal heat indu ... to -PRON- colle...
#  7778  beije fetish restaurant tease … news photograp...
#  7779  iphone case , tozoreg . mm ultrathin perfect f...
#  7780  bbm be so dead , -PRON- have get to chuck this...
#  7781  october , – steve job apple  introduce the wo...
#  7782  i know -PRON- apple new iphone s commercial wi...
#  7783  -PRON- be in love with -PRON- new mobile sony ...
#  7784  crazy kid , always get into something instagra...
#  7785  o i forget , -PRON- can not use the itune stor...
#  7786  pie make everybody make everybody a poet -PRON...
#  7787  so true . plus when i change from macbook pro ...
#  7788  claim -PRON- fame at rt googlebrity android ip...
#  7789  why will itunes not let -PRON- add any music i...
#  7790  hey audiophile , any of -PRON- have or have us...
#  7791  sunset today in zeeland samsung mobile s samsu...
#  7792  sweetjacinta smile ... hey sugar ... i already...
#  7793  the rumour be false . the new iphone do not . ...
#  7794  nice go apple iphone update fix lock phone byp...
#  7795  free lord rangoli … diwali diwali diwalirangol...
#  7796  if i do not have an iphone -PRON- would be asl...
#  7797  apple will be roll out the verizon iphone at v...
#  7798  now between -PRON- asthma allergy , i have no ...
#  7799  microsoft window 's privacy policy be new norm...
#
#  [100 rows x 4 columns],
#          id  label                                              tweet  \
#  7800  7801      0  Follow @capetownsup on Instagram http://mf.tt/...
#  7801  7802      0  Happy New Year! Beaver by Eggtooth http://news...
#  7802  7803      1  #Earpods by apple has to be the most stupidest...
#  7803  7804      0  Gain Followers RT This MUST FOLLOW ME I FOLLOW...
#  7804  7805      0  Its just a bad day.. not a bad life ★ #relax #...
#  7805  7806      1  The fact it cost $150 to replace my fucking sc...
#  7806  7807      1  When you text your boyfriend saying have a 'ni...
#  7807  7808      1  I don't have enough room to take a photo but I...
#  7808  7809      0  Asshole apple. I try to update my phone and it...
#  7809  7810      0  I buy all the newest gadgets and $&@*# from ap...
#  7810  7811      0  #world #Photography day #Canon #Nikon #Sigma #...
#  7811  7812      0  Photo: #new #balance #newbalance #shoes #sexy ...
#  7812  7813      1  Seriously about to switch to #teamandroid firs...
#  7813  7814      0  #iPhone app #theme #preview. We’d your #inputs...
#  7814  7815      1  Well so much for psn going back online this we...
#  7815  7816      1  Jobs, even though you are gone you manage to s...
#  7816  7817      0  RT @boyonthemove92 i was wrong, i iphone wish ...
#  7817  7818      0  I love and am committed to #apple products but...
#  7818  7819      1  Jst cracked my screen n got cut by a piece of ...
#  7819  7820      1  I am beginning to hate #Apple products SO MUCH...
#  7820  7821      1  iPhone 5 lightning cables are the most irritat...
#  7821  7822      0  It's been a $&@*# of a trip [ ]GodZ-WorK, [rVp...
#  7822  7823      0  #iphone #iphonesia #iphoneonly #picoftheday #p...
#  7823  7824      0  #new #case for my #Samsung #galaxy #note3 #min...
#  7824  7825      0  #Nokia Launches New Assault in Patent Battle, ...
#  7825  7826      0  Wedding Day! #wedding #party #carriage #bride ...
#  7826  7827      0  BlackBerry KEYone Phone 4GB RAM Android 7.0 Qw...
#  7827  7828      0  Home from the mall.. Listless but it's worth i...
#  7828  7829      0  It's a happy kiggy #cats #pets #smile #apple #...
#  7829  7830      0  Summer holidays.. #travel #sea #fun #iphone #4...
#  ...    ...    ...                                                ...
#  7870  7871      0  running 10.5.7 and everything looks fine! my i...
#  7871  7872      0  Brain #vocation #newyear #trip #thailand #khao...
#  7872  7873      0  I'm down here! #boston #dog #bostonterrier #pa...
#  7873  7874      0  Welcome home bazooka! We have a great summer a...
#  7874  7875      0  Controversial show ‘Preacher’ gets… http://dlv...
#  7875  7876      0  New t-shirt new iPod #israel #beersheva #ipod ...
#  7876  7877      0  Gain Followers RT This MUST FOLLOW ME I FOLLOW...
#  7877  7878      0  Apple is soo crap. Would never get an iphone h...
#  7878  7879      0  20 years old today #birthday #smile #selfie #h...
#  7879  7880      0  Mondays are usually pretty lame but @SamsungMo...
#  7880  7881      0  I am still in bed at 3 p.m. #LOL Thanks #apple...
#  7881  7882      0  ⓒ Finally found one that fits my phone #iphone...
#  7882  7883      0  We would like to wish you an amazing day! Make...
#  7883  7884      1  Fake sale #VivoSucks just wanted to get traffi...
#  7884  7885      1  iPhone 7 is literally the worst phone. Pointle...
#  7885  7886      0  Moal Boal . . . . . . . . . . . . . . . #iphon...
#  7886  7887      0  Anybody that I usually talk to needs to text m...
#  7887  7888      0  Why does the apple store get everything first....
#  7888  7889      0  The very late Christmas gift from myself to my...
#  7889  7890      1  Okie phone you can die in like two minutes #co...
#  7890  7891      1  Okay I upgraded my phone to an iPhone 6 s & IT...
#  7891  7892      0  New dress, thanks to momma #apple #dress #litt...
#  7892  7893      0  Love recording videos for you guys!! #amazing ...
#  7893  7894      0  Happy Birthday to me:)))) thank you, daddy bir...
#  7894  7895      0  Blue Skys, nothin but blue skies #1  #metroman...
#  7895  7896      1  @KhalSir same here. Have to fork out £120 for ...
#  7896  7897      1  So pissed! Macbook crashes, Apple Company does...
#  7897  7898      1  Slowly moving away from shitty Apple. Goodbye ...
#  7898  7899      0  We would like to wish you an amazing day! Make...
#  7899  7900      0  Early Christmas present?! Sure, dont mind if i...
#
#                                              clean_tweet
#  7800  follow capetownsup on instagram sup surf fun c...
#  7801  happy new year beaver by eggtooth … newsdict n...
#  7802  earpod by apple have to be the most stupid inv...
#  7803  gain follower rt this must follow -PRON- i fol...
#  7804  -PRON- just a bad day .. not a bad life ★ rela...
#  7805  the fact -PRON- cost to replace -PRON- fucking...
#  7806  when -PRON- text -PRON- boyfriend say have a '...
#  7807  i do not have enough room to take a photo but ...
#  7808  asshole apple . i try to update -PRON- phone a...
#  7809  i buy all the new gadget and from apple i swea...
#  7810  world photography day canon nikon sigma leica ...
#  7811  photo new balance newbalance shoe sexy sport -...
#  7812  seriously about to switch to teamandroid first...
#  7813  iphone app theme preview . -PRON- would -PRON-...
#  7814  well so much for psn go back online this weeke...
#  7815  job , even though -PRON- be go -PRON- manage t...
#  7816  rt boyonthemove i be wrong , i iphone wish -PR...
#  7817  i love and be commit to apple product but holy...
#  7818  jst crack -PRON- screen n get cut by a piece o...
#  7819  i be begin to hate apple product so much . so ...
#  7820  iphone lightning cable be the most irritating ...
#  7821  -PRON- be be a of a trip godzwork , rvpruthles...
#  7822  iphone iphonesia iphoneonly picoftheday pic an...
#  7823  new case for -PRON- samsung galaxy note minion...
#  7824  nokia launch new assault in patent battle , -P...
#  7825  wedding day wedding party carriage bride style...
#  7826  blackberry keyone phone gb ram android . qwert...
#  7827  home from the mall .. listless but -PRON- be w...
#  7828  -PRON- be a happy kiggy cat pet smile apple sh...
#  7829  summer holiday .. travel sea fun iphone s inst...
#  ...                                                 ...
#  7870  run . . and everything look fine -PRON- iphone...
#  7871  brain vocation newyear trip thailand khaoko a ...
#  7872  -PRON- be down here boston dog bostonterrier p...
#  7873  welcome home bazooka -PRON- have a great summe...
#  7874  controversial show ‘ preacher ' get … news pho...
#  7875  new tshirt new ipod israel beersheva ipod appl...
#  7876  gain follower rt this must follow -PRON- i fol...
#  7877  apple be soo crap . would never get an iphone ...
#  7878  year old today birthday smile selfie hollister...
#  7879  monday be usually pretty lame but samsungmobil...
#  7880  i be still in bed at p.m. lol thank apple for ...
#  7881  ⓒ finally find one that fit -PRON- phone iphon...
#  7882  -PRON- would like to wish -PRON- an amazing da...
#  7883  fake sale vivosuck just want to get traffic on...
#  7884  iphone be literally the bad phone . pointless ...
#  7885  moal boal . . . . . . . . . . . . . . . iphone...
#  7886  anybody that i usually talk to need to text -P...
#  7887  why do the apple store get everything first . ...
#  7888  the very late christmas gift from -PRON- to -P...
#  7889  okie phone -PRON- can die in like two minute c...
#  7890  okay i upgrade -PRON- phone to an iphone s -PR...
#  7891  new dress , thank to momma apple dress littleb...
#  7892  love record video for -PRON- guy amazing youtu...
#  7893  happy birthday to -PRON- thank -PRON- , daddy ...
#  7894  blue skys , nothing but blue sky metromanb wee...
#  7895  khalsir same here . have to fork out £ for a n...
#  7896  so pissed macbook crash , apple company do not...
#  7897  slowly move away from shitty apple . goodbye a...
#  7898  -PRON- would like to wish -PRON- an amazing da...
#  7899  early christmas present sure , do not mind if ...
#
#  [100 rows x 4 columns],
#          id  label                                              tweet  \
#  7900  7901      0  Why did my iPhone calendar link with my Facebo...
#  7901  7902      1  @brendan_brady1: The new apple advert can fuck...
#  7902  7903      1  All I wanna do is put music from my iTunes on ...
#  7903  7904      0  @KaylaHinks @SnapchatProbbz haha so true. Dele...
#  7904  7905      1  #FuckYou #Apple one thing stops working and I ...
#  7905  7906      0  ove a fist inside my $&@*# Oh #god #i #a #fist...
#  7906  7907      0  Legit feels like I have a brand new phone #app...
#  7907  7908      0  Tipsy rhymes with E, Ye, We, Je, Mi, Ne,... Do...
#  7908  7909      1  SECOND FUCKING TIME. Stay on hold for 30 mins ...
#  7909  7910      0  RT: monteithelgort: First post from my new pho...
#  7910  7911      0  Perfect match #instagood #applewatch #red #ins...
#  7911  7912      0  I am completely in love with the new iPhone em...
#  7912  7913      0  Tune in. Turn on. Drop out. & #GTD in one app!...
#  7913  7914      1  Ok so my galaxy crashed after one day now I ha...
#  7914  7915      0  Gain Followers RT This MUST FOLLOW ME I FOLLOW...
#  7915  7916      0  Live out loud #lol #liveoutloud #selfie #smile...
#  7916  7917      0  We would like to wish you an amazing day! Make...
#  7917  7918      0  Helping my lovely 90 year old neighbor with he...
#  7918  7919      0  Finally got my #smart #pocket #wifi stay conne...
#  7919  7920      0  Apple Barcelona!!! #Apple #Store #BCN #Barcelo...
#
#                                              clean_tweet
#  7900  why do -PRON- iphone calendar link with -PRON-...
#  7901  brendanbrady the new apple advert can fuck off...
#  7902  all i wanna do be put music from -PRON- itune ...
#  7903  kaylahink snapchatprobbz haha so true . delete...
#  7904  fuckyou apple one thing stop work and i have t...
#  7905  ove a fist inside -PRON- oh god i a fist insid...
#  7906  legit feel like i have a brand new phone apple...
#  7907  tipsy rhyme with e , ye , -PRON- , je , mi , n...
#  7908  second fucking time . stay on hold for min and...
#  7909  rt monteithelgort first post from -PRON- new p...
#  7910  perfect match instagood applewatch red instagr...
#  7911  i be completely in love with the new iphone em...
#  7912  tune in . turn on . drop out . gtd in one app ...
#  7913  ok so -PRON- galaxy crash after one day now i ...
#  7914  gain follower rt this must follow -PRON- i fol...
#  7915  live out loud lol liveoutloud selfie smile son...
#  7916  -PRON- would like to wish -PRON- an amazing da...
#  7917  help -PRON- lovely year old neighbor with -PRO...
#  7918  finally get -PRON- smart pocket wifi stay conn...
#  7919  apple barcelona apple store bcn barcelona trav...  ]

# %% [markdown]
# 轉換完成後，使用剛剛載入的 ELMo model 做資料的轉換
#
# 再使用 tf 取得 ELMo vector
#
# 最後把資料轉回 array 的形式

# %%
def elmo_vectors(x):
    embeddings = elmo(x.tolist(), signature="default", as_dict=True)["elmo"]

    with tf.Session() as sess: # 創建一個tensorflow session
        sess.run(tf.global_variables_initializer())
        sess.run(tf.tables_initializer())
        # return average of ELMo features
        return sess.run(tf.reduce_mean(embeddings, 1))  # 取 vector 的平均, 1 代表 column 取平均

elmo_train = [elmo_vectors(x['clean_tweet']) for x in list_train]
# elmo_test = [elmo_vectors(x['clean_tweet']) for x in list_test]

# %%
elmo_train_new = np.concatenate(elmo_train, axis = 0)
# elmo_test_new = np.concatenate(elmo_test, axis = 0)
elmo_train_new
# Out:
# array([[-0.01367856,  0.0471907 ,  0.04993869, ...,  0.00911632,
#          0.02073942,  0.06375235],
#        [-0.04931365, -0.01975196,  0.02596117, ...,  0.03484079,
#          0.05203516, -0.01941845],
#        [-0.07244584, -0.04607351,  0.06534164, ..., -0.00022881,
#         -0.08720941,  0.03318136],
#        ...,
#        [-0.13460152,  0.00312679, -0.16876186, ...,  0.09333538,
#          0.17530221,  0.0798686 ],
#        [ 0.06581538,  0.17325026,  0.06232745, ...,  0.08818179,
#         -0.1882427 ,  0.01674475],
#        [ 0.02453895, -0.10790104,  0.19223242, ..., -0.04737334,
#          0.10106892,  0.13966535]], dtype=float32)

# %% [markdown]
# 因為花費了很多時間做 ELMo vector 的轉換，所以先將轉換的結果存起來 <br>
#
# 使用的 library 是 pickle

# %%
# save elmo_train_new
pickle_out = open("elmo_train_03032019.pickle","wb")
pickle.dump(elmo_train_new, pickle_out)
pickle_out.close()

# save elmo_test_new
# pickle_out = open("elmo_test_03032019.pickle","wb")
# pickle.dump(elmo_test_new, pickle_out)
# pickle_out.close()

# %% [markdown]
# 接著再載入剛剛存的 ELMo vector

# %%
# load elmo_train_new
pickle_in = open("elmo_train_03032019.pickle", "rb")
elmo_train_new = pickle.load(pickle_in)

# load elmo_train_new
# pickle_in = open("elmo_test_03032019.pickle", "rb")
# elmo_test_new = pickle.load(pickle_in)

# %% [markdown]
# 將 ELMo vector 讀取完之後，接著就可以開始訓練模型了

# %% [markdown]
# **step4 : Model Building**
#
# 訓練模型前先準備好 training data 和 testing data

# %%
from sklearn.model_selection import train_test_split

xtrain, xvalid, ytrain, yvalid = train_test_split(elmo_train_new, 
                                                  train['label'],  
                                                  random_state=42, 
                                                  test_size=0.2)

# %% [markdown]
# 接著我們建立 logistic regression model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

lreg = LogisticRegression()
lreg.fit(xtrain, ytrain)
# Out:
# /usr/local/cello/env/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# 成功地建立完分類器後，就可以來預測 testing data

# %%
preds_valid = lreg.predict(xvalid)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(yvalid, preds_valid)
# Out:
# 0.8819444444444444

# %%
from sklearn.metrics import f1_score

f1_score(yvalid, preds_valid)
# Out:
# 0.7776456599286562
